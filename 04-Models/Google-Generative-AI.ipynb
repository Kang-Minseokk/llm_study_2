# %%
# !pip install langchain-google-genai
# !pip install --upgrade langchain
# Out:
# Requirement already satisfied: langchain-google-genai in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (2.0.0)
# Requirement already satisfied: google-generativeai<0.8.0,>=0.7.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-google-genai) (0.7.2)
# Requirement already satisfied: langchain-core<0.4,>=0.3.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-google-genai) (0.3.5)
# Requirement already satisfied: pydantic<3,>=2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-google-genai) (2.8.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.6 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (0.6.6)
# Requirement already satisfied: google-api-core in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.20.0)
# Requirement already satisfied: google-api-python-client in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.147.0)
# Requirement already satisfied: google-auth>=2.15.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.34.0)
# Requirement already satisfied: protobuf in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (4.25.4)
# Requirement already satisfied: tqdm in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (4.66.5)
# Requirement already satisfied: typing-extensions in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-ai-generativelanguage==0.6.6->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (1.24.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai) (0.1.128)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai) (8.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from pydantic<3,>=2->langchain-google-genai) (2.20.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.0->langchain-google-genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (3.10.7)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (4.1.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (1.66.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (3.1.2)
# Requirement already satisfied: anyio in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (4.4.0)
# Requirement already satisfied: certifi in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (1.0.5)
# Requirement already satisfied: idna in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (3.7)
# Requirement already satisfied: sniffio in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.2.2)
# Requirement already satisfied: langchain in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (0.3.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain) (3.10.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain) (0.1.128)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: anyio in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: sniffio in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/minseokkang/projects/llm_study/venvs/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain) (3.0.0)

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_teddynote import logging
from langchain_teddynote.messages import stream_response

logging.langsmith("CH04-Models")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH04-Models

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# ChatGoogleGenerativeAI 언어 모델을 초기화합니다.
llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro")

# 프롬프트를 전달하여 결과를 생성합니다.
answer = llm.stream("자연어처리에 대해서 간략히 설명해 줘")

# 결과를 출력합니다.
stream_response(answer)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from langchain_google_genai import ChatGoogleGenerativeAI
#       3 # ChatGoogleGenerativeAI 언어 모델을 초기화합니다.
#       4 llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro")
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/langchain_google_genai/__init__.py:59
#       1 """**LangChain Google Generative AI Integration**
#       2
#       3 This module integrates Google's Generative AI models, specifically the Gemini series, with the LangChain framework. It provides classes for interacting with chat models and generating embeddings, leveraging Google's advanced AI capabilities.
#    (...)
#      55 ```
#      56 """  # noqa: E501
#      58 from langchain_google_genai._enums import HarmBlockThreshold, HarmCategory
# ---> 59 from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
#      60 from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
#      61 from langchain_google_genai.genai_aqa import (
#      62     AqaInput,
#      63     AqaOutput,
#      64     GenAIAqa,
#      65 )
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:54
#      49 from google.generativeai.types import Tool as GoogleTool  # type: ignore[import]
#      50 from google.generativeai.types.content_types import (  # type: ignore[import]
#      51     FunctionDeclarationType,
#      52     ToolDict,
#      53 )
# ---> 54 from langchain_core.callbacks.manager import (
#      55     AsyncCallbackManagerForLLMRun,
#      56     CallbackManagerForLLMRun,
#      57 )
#      58 from langchain_core.language_models import LanguageModelInput
#      59 from langchain_core.language_models.chat_models import BaseChatModel, LangSmithParams
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/langchain_core/callbacks/__init__.py:23
#      10 from langchain_core.callbacks.base import (
#      11     AsyncCallbackHandler,
#      12     BaseCallbackHandler,
#    (...)
#      20     ToolManagerMixin,
#      21 )
#      22 from langchain_core.callbacks.file import FileCallbackHandler
# ---> 23 from langchain_core.callbacks.manager import (
#      24     AsyncCallbackManager,
#      25     AsyncCallbackManagerForChainGroup,
#      26     AsyncCallbackManagerForChainRun,
#      27     AsyncCallbackManagerForLLMRun,
#      28     AsyncCallbackManagerForRetrieverRun,
#      29     AsyncCallbackManagerForToolRun,
#      30     AsyncParentRunManager,
#      31     AsyncRunManager,
#      32     BaseRunManager,
#      33     CallbackManager,
#      34     CallbackManagerForChainGroup,
#      35     CallbackManagerForChainRun,
#      36     CallbackManagerForLLMRun,
#      37     CallbackManagerForRetrieverRun,
#      38     CallbackManagerForToolRun,
#      39     ParentRunManager,
#      40     RunManager,
#      41     adispatch_custom_event,
#      42     dispatch_custom_event,
#      43 )
#      44 from langchain_core.callbacks.stdout import StdOutCallbackHandler
#      45 from langchain_core.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/langchain_core/callbacks/manager.py:38
#      36 from langchain_core.callbacks.stdout import StdOutCallbackHandler
#      37 from langchain_core.messages import BaseMessage, get_buffer_string
# ---> 38 from langchain_core.tracers.schemas import Run
#      39 from langchain_core.utils.env import env_var_is_set
#      41 if TYPE_CHECKING:
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/langchain_core/tracers/__init__.py:22
#       1 """**Tracers** are classes for tracing runs.
#       2
#       3 **Class hierarchy:**
#    (...)
#       8                                        --> <name>  # Examples: LogStreamCallbackHandler
#       9 """  # noqa: E501
#      11 __all__ = [
#      12     "BaseTracer",
#      13     "EvaluatorCallbackHandler",
#    (...)
#      19     "LogStreamCallbackHandler",
#      20 ]
# ---> 22 from langchain_core.tracers.base import BaseTracer
#      23 from langchain_core.tracers.evaluation import EvaluatorCallbackHandler
#      24 from langchain_core.tracers.langchain import LangChainTracer
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/langchain_core/tracers/base.py:22
#      20 from langchain_core.exceptions import TracerException  # noqa
#      21 from langchain_core.messages import BaseMessage
# ---> 22 from langchain_core.outputs import ChatGenerationChunk, GenerationChunk, LLMResult
#      23 from langchain_core.tracers.core import _TracerCore
#      24 from langchain_core.tracers.schemas import Run
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/langchain_core/outputs/__init__.py:22
#       1 """**Output** classes are used to represent the output of a language model call
#       2 and the output of a chat.
#       3
#    (...)
#      19 from the `LLMResult` object.
#      20 """
# ---> 22 from langchain_core.outputs.chat_generation import ChatGeneration, ChatGenerationChunk
#      23 from langchain_core.outputs.chat_result import ChatResult
#      24 from langchain_core.outputs.generation import Generation, GenerationChunk
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/langchain_core/outputs/chat_generation.py:13
#       9 from langchain_core.outputs.generation import Generation
#      10 from langchain_core.utils._merge import merge_dicts
# ---> 13 class ChatGeneration(Generation):
#      14     """A single chat generation output.
#      15
#      16     A subclass of Generation that represents the response from a chat model
#    (...)
#      24     via callbacks).
#      25     """
#      27     text: str = ""
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/pydantic/v1/main.py:221, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     219 elif is_valid_field(var_name) and var_name not in annotations and can_be_changed:
#     220     validate_field_name(bases, var_name)
# --> 221     inferred = ModelField.infer(
#     222         name=var_name,
#     223         value=value,
#     224         annotation=annotations.get(var_name, Undefined),
#     225         class_validators=vg.get_validators(var_name),
#     226         config=config,
#     227     )
#     228     if var_name in fields:
#     229         if lenient_issubclass(inferred.type_, fields[var_name].type_):
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/pydantic/v1/fields.py:504, in ModelField.infer(cls, name, value, annotation, class_validators, config)
#     501     required = False
#     502 annotation = get_annotation_from_field_info(annotation, field_info, name, config.validate_assignment)
# --> 504 return cls(
#     505     name=name,
#     506     type_=annotation,
#     507     alias=field_info.alias,
#     508     class_validators=class_validators,
#     509     default=value,
#     510     default_factory=field_info.default_factory,
#     511     required=required,
#     512     model_config=config,
#     513     field_info=field_info,
#     514 )
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/pydantic/v1/fields.py:434, in ModelField.__init__(self, name, type_, class_validators, model_config, default, default_factory, required, final, alias, field_info)
#     432 self.shape: int = SHAPE_SINGLETON
#     433 self.model_config.prepare_field(self)
# --> 434 self.prepare()
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/pydantic/v1/fields.py:544, in ModelField.prepare(self)
#     537 def prepare(self) -> None:
#     538     """
#     539     Prepare the field but inspecting self.default, self.type_ etc.
#     540
#     541     Note: this method is **not** idempotent (because _type_analysis is not idempotent),
#     542     e.g. calling it it multiple times may modify the field and configure it incorrectly.
#     543     """
# --> 544     self._set_default_and_type()
#     545     if self.type_.__class__ is ForwardRef or self.type_.__class__ is DeferredType:
#     546         # self.type_ is currently a ForwardRef and there's nothing we can do now,
#     547         # user will need to call model.update_forward_refs()
#     548         return
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/pydantic/v1/fields.py:568, in ModelField._set_default_and_type(self)
#     563         raise errors_.ConfigError(
#     564             f'you need to set the type of field {self.name!r} when using `default_factory`'
#     565         )
#     566     return
# --> 568 default_value = self.get_default()
#     570 if default_value is not None and self.type_ is Undefined:
#     571     self.type_ = default_value.__class__
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/pydantic/v1/fields.py:437, in ModelField.get_default(self)
#     436 def get_default(self) -> Any:
# --> 437     return smart_deepcopy(self.default) if self.default_factory is None else self.default_factory()
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/pydantic/v1/utils.py:693, in smart_deepcopy(obj)
#     689 except (TypeError, ValueError, RuntimeError):
#     690     # do we really dare to catch ALL errors? Seems a bit risky
#     691     pass
# --> 693 return deepcopy(obj)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if deep:
#     259     state = deepcopy(state, memo)
# --> 260 if hasattr(y, '__setstate__'):
#     261     y.__setstate__(state)
#     262 else:
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/pydantic/_internal/_decorators.py:196, in PydanticDescriptorProxy.__getattr__(self, _PydanticDescriptorProxy__name)
#     194 def __getattr__(self, __name: str) -> Any:
#     195     """Forward checks for __isabstractmethod__ and such."""
# --> 196     return getattr(self.wrapped, __name)
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/pydantic/_internal/_decorators.py:196, in PydanticDescriptorProxy.__getattr__(self, _PydanticDescriptorProxy__name)
#     194 def __getattr__(self, __name: str) -> Any:
#     195     """Forward checks for __isabstractmethod__ and such."""
# --> 196     return getattr(self.wrapped, __name)
#
#     [... skipping similar frames: PydanticDescriptorProxy.__getattr__ at line 196 (2911 times)]
#
# File ~/projects/llm_study/venvs/lib/python3.12/site-packages/pydantic/_internal/_decorators.py:196, in PydanticDescriptorProxy.__getattr__(self, _PydanticDescriptorProxy__name)
#     194 def __getattr__(self, __name: str) -> Any:
#     195     """Forward checks for __isabstractmethod__ and such."""
# --> 196     return getattr(self.wrapped, __name)
#
# RecursionError: maximum recursion depth exceeded
